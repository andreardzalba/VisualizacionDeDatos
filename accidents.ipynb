# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('accidents_2012_to_2014.csv')
data.plot('Year','Accident_Severity',kind = 'scatter')
plt.title('Accident index with year')
plt.ylabel('accidents')
# Out:
# Text(0, 0.5, 'accidents')
