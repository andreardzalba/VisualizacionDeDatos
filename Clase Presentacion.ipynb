# %%
# %ls 'datasets/'
# Out:
# adult.csv                  census.csv            pokemon.csv
# airline_data.csv           cwurData.csv          sample_pivot.csv
# antropometria00.csv        data.csv              tips.csv
# antropometria-dataset.csv  headbrain.csv         weight-height.csv
# Canada.xlsx                movies.csv
# Cartwheeldata.csv          nhanes_2015_2016.csv

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('datasets/Cartwheeldata.csv')
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
df.rename(columns={'CWDistance':'Distance',
                  },
         inplace = True)

pd.pivot_table(df,
               index = ['Gender'],
               values = ['Distance','Wingspan','Age'],
              aggfunc = 'mean')
# Out:
#               Age   Distance   Wingspan
# Gender
# F       29.833333  80.250000  61.541667
# M       26.769231  84.538462  70.615385

# %%
import matplotlib.pyplot as plt

df['Wingspan'].plot(kind='hist')

plt.show()
